# %%
import json

with open('Keys.json') as json_file:
    keys = json.load(json_file)

# %%
import tweepy as tp
import time
import os

#credentials for Tweepy
consumer_key = keys['Twitter_Consumer_Key']
consumer_secret = keys['Twitter_Consumer_Secret']
access_token = keys['Twitter_Access_Token']
access_secret = keys['Twitter_Access_Secret']


#login to twitter api
auth = tp.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)
api = tp.API(auth)

## Bot Twitter username is @Lyrics_Bot_LM

api.get_user('@Lyrics_Bot_LM')._json
# Out:
# {'id': 1164934411256659968,
#  'id_str': '1164934411256659968',
#  'name': 'LM Lyric Bot',
#  'screen_name': 'Lyrics_Bot_LM',
#  'location': 'Google Cloud',
#  'profile_location': None,
#  'description': 'I am a music bot.\nI tweet a random verse from a song every 30 minutes.\nI am #LouisPersonalProject002.\nI live in GoogleCloud/Compute Engine/VM Instance.',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 13,
#  'friends_count': 1,
#  'listed_count': 0,
#  'created_at': 'Fri Aug 23 16:16:31 +0000 2019',
#  'favourites_count': 0,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 1076,
#  'lang': None,
#  'status': {'created_at': 'Thu Sep 19 01:30:09 +0000 2019',
#   'id': 1174495862979870720,
#   'id_str': '1174495862979870720',
#   'text': 'I think he wanna be way more than friends, what?\n\nJuice by Lizzo',
#   'truncated': False,
# ...

# %%
api.get_status("1166009503801733121")._json
api.get_status('1166012572769779714')._json
# Out:
# {'created_at': 'Mon Aug 26 15:40:35 +0000 2019',
#  'id': 1166012572769779714,
#  'id_str': '1166012572769779714',
#  'text': 'This is a TweePy Update_Status test2',
#  'truncated': False,
#  'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#  'source': '<a href="https://placeholdernotreal.com" rel="nofollow">Lyrics tweet bot</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1164934411256659968,
#   'id_str': '1164934411256659968',
#   'name': 'LM Lyric Bot',
#   'screen_name': 'Lyrics_Bot_LM',
#   'location': 'Google Cloud',
#   'description': 'I am a music bot.\nI tweet a random verse from a song every 30 minutes.\nI am #LouisPersonalProject002.\nI live in GoogleCloud/Compute Engine/VM Instance.',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
# ...
